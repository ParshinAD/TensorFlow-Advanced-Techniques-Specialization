# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split
from tensorflow.python.keras.utils.vis_utils import plot_model

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
plot_model(model, show_shapes=True, show_layer_names=True, to_file='model.png')
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          1152        input_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          16512       dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           8256        dense_4[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_4[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_5[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 222.9910 - y1_output_loss: 107.2932 - y2_output_loss: 113.8101 - y1_output_root_mean_squared_error: 10.4040 - y2_output_root_mean_squared_error: 10.7121 - val_loss: 36.8676 - val_y1_output_loss: 16.5400 - val_y2_output_loss: 22.2315 - val_y1_output_root_mean_squared_error: 4.0204 - val_y2_output_root_mean_squared_error: 4.5502
# Epoch 2/500
# 614/614 [==============================] - 0s 162us/sample - loss: 31.5290 - y1_output_loss: 12.7496 - y2_output_loss: 19.2012 - y1_output_root_mean_squared_error: 3.5616 - y2_output_root_mean_squared_error: 4.3410 - val_loss: 83.6306 - val_y1_output_loss: 21.0403 - val_y2_output_loss: 60.9105 - val_y1_output_root_mean_squared_error: 4.6469 - val_y2_output_root_mean_squared_error: 7.8764
# Epoch 3/500
# 614/614 [==============================] - 0s 151us/sample - loss: 26.5330 - y1_output_loss: 10.1516 - y2_output_loss: 16.2342 - y1_output_root_mean_squared_error: 3.1955 - y2_output_root_mean_squared_error: 4.0400 - val_loss: 32.5397 - val_y1_output_loss: 10.6167 - val_y2_output_loss: 21.8121 - val_y1_output_root_mean_squared_error: 3.2791 - val_y2_output_root_mean_squared_error: 4.6677
# Epoch 4/500
# 614/614 [==============================] - 0s 142us/sample - loss: 25.1659 - y1_output_loss: 9.5755 - y2_output_loss: 15.7073 - y1_output_root_mean_squared_error: 3.0753 - y2_output_root_mean_squared_error: 3.9634 - val_loss: 29.1346 - val_y1_output_loss: 9.3718 - val_y2_output_loss: 21.1378 - val_y1_output_root_mean_squared_error: 3.0335 - val_y2_output_root_mean_squared_error: 4.4646
# Epoch 5/500
# 614/614 [==============================] - 0s 148us/sample - loss: 22.4317 - y1_output_loss: 8.6478 - y2_output_loss: 13.6085 - y1_output_root_mean_squared_error: 2.9548 - y2_output_root_mean_squared_error: 3.7015 - val_loss: 40.1271 - val_y1_output_loss: 12.4263 - val_y2_output_loss: 27.4683 - val_y1_output_root_mean_squared_error: 3.5508 - val_y2_output_root_mean_squared_error: 5.2459
# Epoch 6/500
# 614/614 [==============================] - 0s 162us/sample - loss: 22.1107 - y1_output_loss: 8.4854 - y2_output_loss: 13.6691 - y1_output_root_mean_squared_error: 2.9194 - y2_output_root_mean_squared_error: 3.6862 - val_loss: 36.4435 - val_y1_output_loss: 12.8248 - val_y2_output_loss: 23.4562 - val_y1_output_root_mean_squared_error: 3.6151 - val_y2_output_root_mean_squared_error: 4.8347
# Epoch 7/500
# 614/614 [==============================] - 0s 145us/sample - loss: 21.9854 - y1_output_loss: 8.7172 - y2_output_loss: 13.5172 - y1_output_root_mean_squared_error: 2.9425 - y2_output_root_mean_squared_error: 3.6506 - val_loss: 21.5249 - val_y1_output_loss: 8.2788 - val_y2_output_loss: 13.8439 - val_y1_output_root_mean_squared_error: 2.8671 - val_y2_output_root_mean_squared_error: 3.6475
# Epoch 8/500
# 614/614 [==============================] - 0s 142us/sample - loss: 21.0091 - y1_output_loss: 8.1269 - y2_output_loss: 12.7285 - y1_output_root_mean_squared_error: 2.8625 - y2_output_root_mean_squared_error: 3.5798 - val_loss: 19.5728 - val_y1_output_loss: 8.3911 - val_y2_output_loss: 11.8010 - val_y1_output_root_mean_squared_error: 2.8911 - val_y2_output_root_mean_squared_error: 3.3488
# Epoch 9/500
# 614/614 [==============================] - 0s 142us/sample - loss: 20.8680 - y1_output_loss: 8.2590 - y2_output_loss: 12.7293 - y1_output_root_mean_squared_error: 2.8785 - y2_output_root_mean_squared_error: 3.5472 - val_loss: 45.8234 - val_y1_output_loss: 13.4382 - val_y2_output_loss: 32.1222 - val_y1_output_root_mean_squared_error: 3.6958 - val_y2_output_root_mean_squared_error: 5.6714
# Epoch 10/500
# 614/614 [==============================] - 0s 137us/sample - loss: 22.9782 - y1_output_loss: 8.4294 - y2_output_loss: 14.7417 - y1_output_root_mean_squared_error: 2.8930 - y2_output_root_mean_squared_error: 3.8221 - val_loss: 67.2541 - val_y1_output_loss: 14.2089 - val_y2_output_loss: 54.9947 - val_y1_output_root_mean_squared_error: 3.7524 - val_y2_output_root_mean_squared_error: 7.2920
# Epoch 11/500
# 614/614 [==============================] - 0s 143us/sample - loss: 23.3798 - y1_output_loss: 8.5905 - y2_output_loss: 14.5748 - y1_output_root_mean_squared_error: 2.9439 - y2_output_root_mean_squared_error: 3.8358 - val_loss: 49.8298 - val_y1_output_loss: 12.9011 - val_y2_output_loss: 38.3002 - val_y1_output_root_mean_squared_error: 3.5846 - val_y2_output_root_mean_squared_error: 6.0812
# Epoch 12/500
# 614/614 [==============================] - 0s 140us/sample - loss: 20.8967 - y1_output_loss: 8.0092 - y2_output_loss: 12.7111 - y1_output_root_mean_squared_error: 2.8429 - y2_output_root_mean_squared_error: 3.5798 - val_loss: 17.8656 - val_y1_output_loss: 7.1186 - val_y2_output_loss: 11.2192 - val_y1_output_root_mean_squared_error: 2.6833 - val_y2_output_root_mean_squared_error: 3.2658
# Epoch 13/500
# 614/614 [==============================] - 0s 138us/sample - loss: 18.7911 - y1_output_loss: 7.3267 - y2_output_loss: 11.4298 - y1_output_root_mean_squared_error: 2.7043 - y2_output_root_mean_squared_error: 3.3879 - val_loss: 16.0024 - val_y1_output_loss: 6.2938 - val_y2_output_loss: 9.7429 - val_y1_output_root_mean_squared_error: 2.5343 - val_y2_output_root_mean_squared_error: 3.0951
# Epoch 14/500
# 614/614 [==============================] - 0s 136us/sample - loss: 18.3035 - y1_output_loss: 7.2500 - y2_output_loss: 11.5105 - y1_output_root_mean_squared_error: 2.6719 - y2_output_root_mean_squared_error: 3.3413 - val_loss: 71.8930 - val_y1_output_loss: 11.9116 - val_y2_output_loss: 61.7528 - val_y1_output_root_mean_squared_error: 3.4449 - val_y2_output_root_mean_squared_error: 7.7476
# Epoch 15/500
# 614/614 [==============================] - 0s 141us/sample - loss: 16.5486 - y1_output_loss: 6.5147 - y2_output_loss: 9.9073 - y1_output_root_mean_squared_error: 2.5631 - y2_output_root_mean_squared_error: 3.1590 - val_loss: 15.4287 - val_y1_output_loss: 6.0866 - val_y2_output_loss: 9.6326 - val_y1_output_root_mean_squared_error: 2.4849 - val_y2_output_root_mean_squared_error: 3.0421
# Epoch 16/500
# 614/614 [==============================] - 0s 140us/sample - loss: 16.5645 - y1_output_loss: 6.5278 - y2_output_loss: 10.0678 - y1_output_root_mean_squared_error: 2.5560 - y2_output_root_mean_squared_error: 3.1672 - val_loss: 19.4887 - val_y1_output_loss: 7.5726 - val_y2_output_loss: 12.4611 - val_y1_output_root_mean_squared_error: 2.7553 - val_y2_output_root_mean_squared_error: 3.4492
# Epoch 17/500
# 614/614 [==============================] - 0s 138us/sample - loss: 15.5755 - y1_output_loss: 6.3666 - y2_output_loss: 9.1731 - y1_output_root_mean_squared_error: 2.5316 - y2_output_root_mean_squared_error: 3.0276 - val_loss: 15.3371 - val_y1_output_loss: 6.1388 - val_y2_output_loss: 9.3634 - val_y1_output_root_mean_squared_error: 2.4914 - val_y2_output_root_mean_squared_error: 3.0216
# Epoch 18/500
# 614/614 [==============================] - 0s 136us/sample - loss: 15.3515 - y1_output_loss: 5.8027 - y2_output_loss: 9.4697 - y1_output_root_mean_squared_error: 2.4178 - y2_output_root_mean_squared_error: 3.0831 - val_loss: 42.9391 - val_y1_output_loss: 9.1842 - val_y2_output_loss: 33.1492 - val_y1_output_root_mean_squared_error: 3.0654 - val_y2_output_root_mean_squared_error: 5.7916
# Epoch 19/500
# 614/614 [==============================] - 0s 138us/sample - loss: 14.3485 - y1_output_loss: 5.7519 - y2_output_loss: 8.6113 - y1_output_root_mean_squared_error: 2.3962 - y2_output_root_mean_squared_error: 2.9337 - val_loss: 15.1037 - val_y1_output_loss: 5.9323 - val_y2_output_loss: 9.6845 - val_y1_output_root_mean_squared_error: 2.4382 - val_y2_output_root_mean_squared_error: 3.0264
# Epoch 20/500
# 614/614 [==============================] - 0s 138us/sample - loss: 14.8615 - y1_output_loss: 5.9792 - y2_output_loss: 8.7860 - y1_output_root_mean_squared_error: 2.4519 - y2_output_root_mean_squared_error: 2.9749 - val_loss: 13.5918 - val_y1_output_loss: 4.8392 - val_y2_output_loss: 8.9926 - val_y1_output_root_mean_squared_error: 2.2165 - val_y2_output_root_mean_squared_error: 2.9460
# Epoch 21/500
# 614/614 [==============================] - 0s 136us/sample - loss: 14.2065 - y1_output_loss: 5.2970 - y2_output_loss: 8.8756 - y1_output_root_mean_squared_error: 2.3029 - y2_output_root_mean_squared_error: 2.9838 - val_loss: 13.9065 - val_y1_output_loss: 4.7491 - val_y2_output_loss: 9.4776 - val_y1_output_root_mean_squared_error: 2.2004 - val_y2_output_root_mean_squared_error: 3.0108
# Epoch 22/500
# 614/614 [==============================] - 0s 145us/sample - loss: 13.9997 - y1_output_loss: 5.2416 - y2_output_loss: 8.6281 - y1_output_root_mean_squared_error: 2.3000 - y2_output_root_mean_squared_error: 2.9512 - val_loss: 14.5239 - val_y1_output_loss: 5.2876 - val_y2_output_loss: 9.7421 - val_y1_output_root_mean_squared_error: 2.3014 - val_y2_output_root_mean_squared_error: 3.0376
# Epoch 23/500
# 614/614 [==============================] - 0s 139us/sample - loss: 15.1990 - y1_output_loss: 5.4493 - y2_output_loss: 9.6282 - y1_output_root_mean_squared_error: 2.3411 - y2_output_root_mean_squared_error: 3.1174 - val_loss: 14.9141 - val_y1_output_loss: 4.4637 - val_y2_output_loss: 10.1670 - val_y1_output_root_mean_squared_error: 2.1462 - val_y2_output_root_mean_squared_error: 3.2106
# Epoch 24/500
# 614/614 [==============================] - 0s 142us/sample - loss: 12.7793 - y1_output_loss: 4.8309 - y2_output_loss: 8.0226 - y1_output_root_mean_squared_error: 2.2000 - y2_output_root_mean_squared_error: 2.8176 - val_loss: 24.1229 - val_y1_output_loss: 7.3520 - val_y2_output_loss: 17.5974 - val_y1_output_root_mean_squared_error: 2.7099 - val_y2_output_root_mean_squared_error: 4.0962
# Epoch 25/500
# 614/614 [==============================] - 0s 147us/sample - loss: 13.4148 - y1_output_loss: 5.0365 - y2_output_loss: 8.4171 - y1_output_root_mean_squared_error: 2.2385 - y2_output_root_mean_squared_error: 2.8990 - val_loss: 27.9634 - val_y1_output_loss: 9.2877 - val_y2_output_loss: 19.7083 - val_y1_output_root_mean_squared_error: 3.0276 - val_y2_output_root_mean_squared_error: 4.3356
# Epoch 26/500
# 614/614 [==============================] - 0s 141us/sample - loss: 13.4593 - y1_output_loss: 5.0764 - y2_output_loss: 8.3806 - y1_output_root_mean_squared_error: 2.2529 - y2_output_root_mean_squared_error: 2.8955 - val_loss: 16.8085 - val_y1_output_loss: 5.0479 - val_y2_output_loss: 12.4132 - val_y1_output_root_mean_squared_error: 2.2479 - val_y2_output_root_mean_squared_error: 3.4286
# Epoch 27/500
# 614/614 [==============================] - 0s 137us/sample - loss: 13.9591 - y1_output_loss: 5.0144 - y2_output_loss: 8.8793 - y1_output_root_mean_squared_error: 2.2358 - y2_output_root_mean_squared_error: 2.9933 - val_loss: 10.7384 - val_y1_output_loss: 3.7624 - val_y2_output_loss: 7.2039 - val_y1_output_root_mean_squared_error: 1.9566 - val_y2_output_root_mean_squared_error: 2.6287
# Epoch 28/500
# 614/614 [==============================] - 0s 138us/sample - loss: 10.8554 - y1_output_loss: 4.1705 - y2_output_loss: 6.6608 - y1_output_root_mean_squared_error: 2.0364 - y2_output_root_mean_squared_error: 2.5900 - val_loss: 11.8585 - val_y1_output_loss: 4.1633 - val_y2_output_loss: 8.0070 - val_y1_output_root_mean_squared_error: 2.0432 - val_y2_output_root_mean_squared_error: 2.7719
# Epoch 29/500
# 614/614 [==============================] - 0s 135us/sample - loss: 12.0577 - y1_output_loss: 4.3626 - y2_output_loss: 7.7863 - y1_output_root_mean_squared_error: 2.0856 - y2_output_root_mean_squared_error: 2.7763 - val_loss: 15.6589 - val_y1_output_loss: 4.3097 - val_y2_output_loss: 11.1165 - val_y1_output_root_mean_squared_error: 2.0998 - val_y2_output_root_mean_squared_error: 3.3541
# Epoch 30/500
# 614/614 [==============================] - 0s 136us/sample - loss: 10.5596 - y1_output_loss: 3.9479 - y2_output_loss: 6.5455 - y1_output_root_mean_squared_error: 1.9896 - y2_output_root_mean_squared_error: 2.5693 - val_loss: 10.5808 - val_y1_output_loss: 3.3697 - val_y2_output_loss: 7.4805 - val_y1_output_root_mean_squared_error: 1.8532 - val_y2_output_root_mean_squared_error: 2.6733
# Epoch 31/500
# 614/614 [==============================] - 0s 134us/sample - loss: 12.4675 - y1_output_loss: 4.2557 - y2_output_loss: 8.2138 - y1_output_root_mean_squared_error: 2.0561 - y2_output_root_mean_squared_error: 2.8706 - val_loss: 21.8044 - val_y1_output_loss: 5.7980 - val_y2_output_loss: 16.7618 - val_y1_output_root_mean_squared_error: 2.4035 - val_y2_output_root_mean_squared_error: 4.0035
# Epoch 32/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.8497 - y1_output_loss: 3.3665 - y2_output_loss: 5.5180 - y1_output_root_mean_squared_error: 1.8338 - y2_output_root_mean_squared_error: 2.3424 - val_loss: 17.1148 - val_y1_output_loss: 4.6297 - val_y2_output_loss: 13.0690 - val_y1_output_root_mean_squared_error: 2.1536 - val_y2_output_root_mean_squared_error: 3.5323
# Epoch 33/500
# 614/614 [==============================] - 0s 135us/sample - loss: 10.6157 - y1_output_loss: 3.7402 - y2_output_loss: 6.8384 - y1_output_root_mean_squared_error: 1.9363 - y2_output_root_mean_squared_error: 2.6204 - val_loss: 17.1548 - val_y1_output_loss: 5.0283 - val_y2_output_loss: 12.8378 - val_y1_output_root_mean_squared_error: 2.2271 - val_y2_output_root_mean_squared_error: 3.4921
# Epoch 34/500
# 614/614 [==============================] - 0s 134us/sample - loss: 9.5182 - y1_output_loss: 3.3525 - y2_output_loss: 6.1026 - y1_output_root_mean_squared_error: 1.8349 - y2_output_root_mean_squared_error: 2.4802 - val_loss: 10.3052 - val_y1_output_loss: 3.3183 - val_y2_output_loss: 7.2285 - val_y1_output_root_mean_squared_error: 1.8290 - val_y2_output_root_mean_squared_error: 2.6382
# Epoch 35/500
# 614/614 [==============================] - 0s 135us/sample - loss: 11.0519 - y1_output_loss: 3.6594 - y2_output_loss: 7.3332 - y1_output_root_mean_squared_error: 1.9212 - y2_output_root_mean_squared_error: 2.7131 - val_loss: 8.8495 - val_y1_output_loss: 2.8936 - val_y2_output_loss: 6.0059 - val_y1_output_root_mean_squared_error: 1.7168 - val_y2_output_root_mean_squared_error: 2.4294
# Epoch 36/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.1689 - y1_output_loss: 2.8830 - y2_output_loss: 5.2267 - y1_output_root_mean_squared_error: 1.7038 - y2_output_root_mean_squared_error: 2.2947 - val_loss: 11.6057 - val_y1_output_loss: 2.8917 - val_y2_output_loss: 9.1795 - val_y1_output_root_mean_squared_error: 1.6981 - val_y2_output_root_mean_squared_error: 2.9533
# Epoch 37/500
# 614/614 [==============================] - 0s 142us/sample - loss: 9.8703 - y1_output_loss: 3.2952 - y2_output_loss: 6.4956 - y1_output_root_mean_squared_error: 1.8216 - y2_output_root_mean_squared_error: 2.5597 - val_loss: 12.3298 - val_y1_output_loss: 3.8824 - val_y2_output_loss: 8.9175 - val_y1_output_root_mean_squared_error: 1.9679 - val_y2_output_root_mean_squared_error: 2.9081
# Epoch 38/500
# 614/614 [==============================] - 0s 140us/sample - loss: 8.0536 - y1_output_loss: 2.6455 - y2_output_loss: 5.3833 - y1_output_root_mean_squared_error: 1.6305 - y2_output_root_mean_squared_error: 2.3227 - val_loss: 30.2294 - val_y1_output_loss: 9.1605 - val_y2_output_loss: 20.1690 - val_y1_output_root_mean_squared_error: 3.0764 - val_y2_output_root_mean_squared_error: 4.5569
# Epoch 39/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.7343 - y1_output_loss: 2.7029 - y2_output_loss: 4.9968 - y1_output_root_mean_squared_error: 1.6510 - y2_output_root_mean_squared_error: 2.2380 - val_loss: 7.9722 - val_y1_output_loss: 2.4855 - val_y2_output_loss: 5.6001 - val_y1_output_root_mean_squared_error: 1.5715 - val_y2_output_root_mean_squared_error: 2.3458
# Epoch 40/500
# 614/614 [==============================] - 0s 139us/sample - loss: 7.9404 - y1_output_loss: 2.6616 - y2_output_loss: 5.2166 - y1_output_root_mean_squared_error: 1.6366 - y2_output_root_mean_squared_error: 2.2939 - val_loss: 8.1249 - val_y1_output_loss: 2.3704 - val_y2_output_loss: 5.7880 - val_y1_output_root_mean_squared_error: 1.5535 - val_y2_output_root_mean_squared_error: 2.3899
# Epoch 41/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.0504 - y1_output_loss: 2.3706 - y2_output_loss: 4.6596 - y1_output_root_mean_squared_error: 1.5353 - y2_output_root_mean_squared_error: 2.1664 - val_loss: 7.7248 - val_y1_output_loss: 2.1283 - val_y2_output_loss: 5.7345 - val_y1_output_root_mean_squared_error: 1.4695 - val_y2_output_root_mean_squared_error: 2.3591
# Epoch 42/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.8962 - y1_output_loss: 2.6553 - y2_output_loss: 6.2198 - y1_output_root_mean_squared_error: 1.6265 - y2_output_root_mean_squared_error: 2.5002 - val_loss: 7.7768 - val_y1_output_loss: 1.9939 - val_y2_output_loss: 6.0083 - val_y1_output_root_mean_squared_error: 1.4211 - val_y2_output_root_mean_squared_error: 2.3994
# Epoch 43/500
# 614/614 [==============================] - 0s 139us/sample - loss: 7.1061 - y1_output_loss: 2.3481 - y2_output_loss: 4.7145 - y1_output_root_mean_squared_error: 1.5347 - y2_output_root_mean_squared_error: 2.1796 - val_loss: 7.8220 - val_y1_output_loss: 2.2640 - val_y2_output_loss: 5.6512 - val_y1_output_root_mean_squared_error: 1.5169 - val_y2_output_root_mean_squared_error: 2.3497
# Epoch 44/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.4070 - y1_output_loss: 2.2424 - y2_output_loss: 5.1081 - y1_output_root_mean_squared_error: 1.5035 - y2_output_root_mean_squared_error: 2.2686 - val_loss: 7.7545 - val_y1_output_loss: 2.2391 - val_y2_output_loss: 5.5644 - val_y1_output_root_mean_squared_error: 1.5105 - val_y2_output_root_mean_squared_error: 2.3394
# Epoch 45/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.7679 - y1_output_loss: 2.1466 - y2_output_loss: 4.5618 - y1_output_root_mean_squared_error: 1.4711 - y2_output_root_mean_squared_error: 2.1456 - val_loss: 9.4786 - val_y1_output_loss: 2.3768 - val_y2_output_loss: 7.3581 - val_y1_output_root_mean_squared_error: 1.5519 - val_y2_output_root_mean_squared_error: 2.6590
# Epoch 46/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.0810 - y1_output_loss: 2.0017 - y2_output_loss: 5.0240 - y1_output_root_mean_squared_error: 1.4201 - y2_output_root_mean_squared_error: 2.2504 - val_loss: 7.7941 - val_y1_output_loss: 1.7909 - val_y2_output_loss: 6.1617 - val_y1_output_root_mean_squared_error: 1.3512 - val_y2_output_root_mean_squared_error: 2.4430
# Epoch 47/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.5631 - y1_output_loss: 1.9490 - y2_output_loss: 4.6494 - y1_output_root_mean_squared_error: 1.3925 - y2_output_root_mean_squared_error: 2.1504 - val_loss: 15.6632 - val_y1_output_loss: 3.1397 - val_y2_output_loss: 12.2033 - val_y1_output_root_mean_squared_error: 1.7969 - val_y2_output_root_mean_squared_error: 3.5262
# Epoch 48/500
# 614/614 [==============================] - 0s 144us/sample - loss: 7.3036 - y1_output_loss: 2.3037 - y2_output_loss: 4.9884 - y1_output_root_mean_squared_error: 1.5155 - y2_output_root_mean_squared_error: 2.2376 - val_loss: 11.4810 - val_y1_output_loss: 4.1575 - val_y2_output_loss: 7.1896 - val_y1_output_root_mean_squared_error: 2.0682 - val_y2_output_root_mean_squared_error: 2.6839
# Epoch 49/500
# 614/614 [==============================] - 0s 138us/sample - loss: 10.1336 - y1_output_loss: 3.3362 - y2_output_loss: 6.7025 - y1_output_root_mean_squared_error: 1.8352 - y2_output_root_mean_squared_error: 2.6011 - val_loss: 6.6958 - val_y1_output_loss: 1.7357 - val_y2_output_loss: 5.0509 - val_y1_output_root_mean_squared_error: 1.3365 - val_y2_output_root_mean_squared_error: 2.2157
# Epoch 50/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.4105 - y1_output_loss: 1.9843 - y2_output_loss: 4.4014 - y1_output_root_mean_squared_error: 1.4145 - y2_output_root_mean_squared_error: 2.1000 - val_loss: 8.3042 - val_y1_output_loss: 2.2664 - val_y2_output_loss: 6.2339 - val_y1_output_root_mean_squared_error: 1.5160 - val_y2_output_root_mean_squared_error: 2.4507
# Epoch 51/500
# 614/614 [==============================] - 0s 142us/sample - loss: 7.5154 - y1_output_loss: 2.2377 - y2_output_loss: 5.2462 - y1_output_root_mean_squared_error: 1.4967 - y2_output_root_mean_squared_error: 2.2968 - val_loss: 7.4768 - val_y1_output_loss: 2.1692 - val_y2_output_loss: 5.3419 - val_y1_output_root_mean_squared_error: 1.4707 - val_y2_output_root_mean_squared_error: 2.3052
# Epoch 52/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.2126 - y1_output_loss: 1.9088 - y2_output_loss: 4.2748 - y1_output_root_mean_squared_error: 1.3794 - y2_output_root_mean_squared_error: 2.0760 - val_loss: 5.8024 - val_y1_output_loss: 1.3469 - val_y2_output_loss: 4.5342 - val_y1_output_root_mean_squared_error: 1.1742 - val_y2_output_root_mean_squared_error: 2.1032
# Epoch 53/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.1687 - y1_output_loss: 1.5006 - y2_output_loss: 3.7469 - y1_output_root_mean_squared_error: 1.2160 - y2_output_root_mean_squared_error: 1.9210 - val_loss: 6.4401 - val_y1_output_loss: 1.5467 - val_y2_output_loss: 4.9026 - val_y1_output_root_mean_squared_error: 1.2555 - val_y2_output_root_mean_squared_error: 2.2054
# Epoch 54/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.7514 - y1_output_loss: 2.0825 - y2_output_loss: 4.9514 - y1_output_root_mean_squared_error: 1.4279 - y2_output_root_mean_squared_error: 2.1708 - val_loss: 50.1550 - val_y1_output_loss: 12.7199 - val_y2_output_loss: 36.4598 - val_y1_output_root_mean_squared_error: 3.5969 - val_y2_output_root_mean_squared_error: 6.1006
# Epoch 55/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.2937 - y1_output_loss: 2.3527 - y2_output_loss: 5.9389 - y1_output_root_mean_squared_error: 1.5393 - y2_output_root_mean_squared_error: 2.4339 - val_loss: 13.8423 - val_y1_output_loss: 2.6617 - val_y2_output_loss: 10.8805 - val_y1_output_root_mean_squared_error: 1.6497 - val_y2_output_root_mean_squared_error: 3.3348
# Epoch 56/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.0358 - y1_output_loss: 1.8166 - y2_output_loss: 4.1868 - y1_output_root_mean_squared_error: 1.3468 - y2_output_root_mean_squared_error: 2.0547 - val_loss: 5.9970 - val_y1_output_loss: 1.5012 - val_y2_output_loss: 4.5378 - val_y1_output_root_mean_squared_error: 1.2391 - val_y2_output_root_mean_squared_error: 2.1123
# Epoch 57/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.7738 - y1_output_loss: 1.6021 - y2_output_loss: 4.1463 - y1_output_root_mean_squared_error: 1.2679 - y2_output_root_mean_squared_error: 2.0411 - val_loss: 9.6332 - val_y1_output_loss: 2.1186 - val_y2_output_loss: 7.8385 - val_y1_output_root_mean_squared_error: 1.4662 - val_y2_output_root_mean_squared_error: 2.7356
# Epoch 58/500
# 614/614 [==============================] - 0s 139us/sample - loss: 12.7361 - y1_output_loss: 3.6580 - y2_output_loss: 9.0042 - y1_output_root_mean_squared_error: 1.9201 - y2_output_root_mean_squared_error: 3.0082 - val_loss: 9.6771 - val_y1_output_loss: 2.2683 - val_y2_output_loss: 7.3430 - val_y1_output_root_mean_squared_error: 1.5341 - val_y2_output_root_mean_squared_error: 2.7062
# Epoch 59/500
# 614/614 [==============================] - 0s 144us/sample - loss: 5.8067 - y1_output_loss: 1.7373 - y2_output_loss: 4.0443 - y1_output_root_mean_squared_error: 1.3187 - y2_output_root_mean_squared_error: 2.0169 - val_loss: 5.8753 - val_y1_output_loss: 1.1439 - val_y2_output_loss: 4.9670 - val_y1_output_root_mean_squared_error: 1.0791 - val_y2_output_root_mean_squared_error: 2.1704
# Epoch 60/500
# 614/614 [==============================] - 0s 144us/sample - loss: 5.3349 - y1_output_loss: 1.4648 - y2_output_loss: 3.8722 - y1_output_root_mean_squared_error: 1.2015 - y2_output_root_mean_squared_error: 1.9726 - val_loss: 7.8326 - val_y1_output_loss: 1.1739 - val_y2_output_loss: 7.0040 - val_y1_output_root_mean_squared_error: 1.0977 - val_y2_output_root_mean_squared_error: 2.5744
# Epoch 61/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.6390 - y1_output_loss: 1.3537 - y2_output_loss: 3.2436 - y1_output_root_mean_squared_error: 1.1687 - y2_output_root_mean_squared_error: 1.8092 - val_loss: 6.0489 - val_y1_output_loss: 1.2897 - val_y2_output_loss: 4.8593 - val_y1_output_root_mean_squared_error: 1.1518 - val_y2_output_root_mean_squared_error: 2.1731
# Epoch 62/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.1597 - y1_output_loss: 2.0918 - y2_output_loss: 5.0449 - y1_output_root_mean_squared_error: 1.4407 - y2_output_root_mean_squared_error: 2.2548 - val_loss: 11.5231 - val_y1_output_loss: 2.6373 - val_y2_output_loss: 9.1232 - val_y1_output_root_mean_squared_error: 1.6425 - val_y2_output_root_mean_squared_error: 2.9707
# Epoch 63/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.9993 - y1_output_loss: 1.3043 - y2_output_loss: 3.7556 - y1_output_root_mean_squared_error: 1.1405 - y2_output_root_mean_squared_error: 1.9232 - val_loss: 8.6220 - val_y1_output_loss: 1.6444 - val_y2_output_loss: 6.8535 - val_y1_output_root_mean_squared_error: 1.2941 - val_y2_output_root_mean_squared_error: 2.6358
# Epoch 64/500
# 614/614 [==============================] - 0s 143us/sample - loss: 5.5777 - y1_output_loss: 1.5705 - y2_output_loss: 3.9705 - y1_output_root_mean_squared_error: 1.2579 - y2_output_root_mean_squared_error: 1.9989 - val_loss: 5.8327 - val_y1_output_loss: 1.5309 - val_y2_output_loss: 4.4713 - val_y1_output_root_mean_squared_error: 1.2492 - val_y2_output_root_mean_squared_error: 2.0670
# Epoch 65/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.3264 - y1_output_loss: 1.6715 - y2_output_loss: 3.6380 - y1_output_root_mean_squared_error: 1.2904 - y2_output_root_mean_squared_error: 1.9134 - val_loss: 6.3009 - val_y1_output_loss: 1.0481 - val_y2_output_loss: 5.4774 - val_y1_output_root_mean_squared_error: 1.0391 - val_y2_output_root_mean_squared_error: 2.2850
# Epoch 66/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.9163 - y1_output_loss: 1.0673 - y2_output_loss: 2.8390 - y1_output_root_mean_squared_error: 1.0315 - y2_output_root_mean_squared_error: 1.6889 - val_loss: 4.6878 - val_y1_output_loss: 0.8263 - val_y2_output_loss: 3.8773 - val_y1_output_root_mean_squared_error: 0.9179 - val_y2_output_root_mean_squared_error: 1.9609
# Epoch 67/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.8386 - y1_output_loss: 1.2931 - y2_output_loss: 3.5116 - y1_output_root_mean_squared_error: 1.1382 - y2_output_root_mean_squared_error: 1.8823 - val_loss: 4.2972 - val_y1_output_loss: 0.7562 - val_y2_output_loss: 3.6073 - val_y1_output_root_mean_squared_error: 0.8792 - val_y2_output_root_mean_squared_error: 1.8773
# Epoch 68/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.0328 - y1_output_loss: 1.1414 - y2_output_loss: 4.0506 - y1_output_root_mean_squared_error: 1.0679 - y2_output_root_mean_squared_error: 1.9729 - val_loss: 26.9149 - val_y1_output_loss: 5.6722 - val_y2_output_loss: 22.1945 - val_y1_output_root_mean_squared_error: 2.3686 - val_y2_output_root_mean_squared_error: 4.6157
# Epoch 69/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.0356 - y1_output_loss: 1.3217 - y2_output_loss: 3.8373 - y1_output_root_mean_squared_error: 1.1343 - y2_output_root_mean_squared_error: 1.9362 - val_loss: 23.2029 - val_y1_output_loss: 6.8843 - val_y2_output_loss: 16.0344 - val_y1_output_root_mean_squared_error: 2.6347 - val_y2_output_root_mean_squared_error: 4.0325
# Epoch 70/500
# 614/614 [==============================] - 0s 143us/sample - loss: 4.4428 - y1_output_loss: 1.1523 - y2_output_loss: 3.3804 - y1_output_root_mean_squared_error: 1.0422 - y2_output_root_mean_squared_error: 1.8321 - val_loss: 8.5097 - val_y1_output_loss: 2.8987 - val_y2_output_loss: 5.7840 - val_y1_output_root_mean_squared_error: 1.7079 - val_y2_output_root_mean_squared_error: 2.3649
# Epoch 71/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.5929 - y1_output_loss: 0.8838 - y2_output_loss: 2.6877 - y1_output_root_mean_squared_error: 0.9426 - y2_output_root_mean_squared_error: 1.6445 - val_loss: 6.5316 - val_y1_output_loss: 1.5471 - val_y2_output_loss: 4.9288 - val_y1_output_root_mean_squared_error: 1.2569 - val_y2_output_root_mean_squared_error: 2.2253
# Epoch 72/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.3933 - y1_output_loss: 1.0852 - y2_output_loss: 3.3061 - y1_output_root_mean_squared_error: 1.0354 - y2_output_root_mean_squared_error: 1.8224 - val_loss: 4.9906 - val_y1_output_loss: 1.0924 - val_y2_output_loss: 3.9967 - val_y1_output_root_mean_squared_error: 1.0642 - val_y2_output_root_mean_squared_error: 1.9642
# Epoch 73/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.3756 - y1_output_loss: 0.7780 - y2_output_loss: 2.5984 - y1_output_root_mean_squared_error: 0.8851 - y2_output_root_mean_squared_error: 1.6100 - val_loss: 4.7026 - val_y1_output_loss: 0.7244 - val_y2_output_loss: 4.0256 - val_y1_output_root_mean_squared_error: 0.8506 - val_y2_output_root_mean_squared_error: 1.9948
# Epoch 74/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.3836 - y1_output_loss: 1.4404 - y2_output_loss: 3.9492 - y1_output_root_mean_squared_error: 1.2034 - y2_output_root_mean_squared_error: 1.9838 - val_loss: 5.6358 - val_y1_output_loss: 0.9913 - val_y2_output_loss: 4.8441 - val_y1_output_root_mean_squared_error: 1.0037 - val_y2_output_root_mean_squared_error: 2.1513
# Epoch 75/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.7432 - y1_output_loss: 1.4007 - y2_output_loss: 4.4337 - y1_output_root_mean_squared_error: 1.1860 - y2_output_root_mean_squared_error: 2.0825 - val_loss: 10.5818 - val_y1_output_loss: 1.7844 - val_y2_output_loss: 8.7143 - val_y1_output_root_mean_squared_error: 1.3470 - val_y2_output_root_mean_squared_error: 2.9610
# Epoch 76/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.8250 - y1_output_loss: 0.8981 - y2_output_loss: 2.9192 - y1_output_root_mean_squared_error: 0.9468 - y2_output_root_mean_squared_error: 1.7113 - val_loss: 11.1919 - val_y1_output_loss: 2.5187 - val_y2_output_loss: 8.9621 - val_y1_output_root_mean_squared_error: 1.5981 - val_y2_output_root_mean_squared_error: 2.9390
# Epoch 77/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.1239 - y1_output_loss: 0.8622 - y2_output_loss: 3.2404 - y1_output_root_mean_squared_error: 0.9287 - y2_output_root_mean_squared_error: 1.8059 - val_loss: 3.5613 - val_y1_output_loss: 0.5356 - val_y2_output_loss: 3.1040 - val_y1_output_root_mean_squared_error: 0.7428 - val_y2_output_root_mean_squared_error: 1.7348
# Epoch 78/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.0078 - y1_output_loss: 1.0884 - y2_output_loss: 3.1380 - y1_output_root_mean_squared_error: 0.9984 - y2_output_root_mean_squared_error: 1.7352 - val_loss: 53.7690 - val_y1_output_loss: 16.7999 - val_y2_output_loss: 37.0326 - val_y1_output_root_mean_squared_error: 4.1382 - val_y2_output_root_mean_squared_error: 6.0535
# Epoch 79/500
# 614/614 [==============================] - 0s 150us/sample - loss: 8.2696 - y1_output_loss: 2.3264 - y2_output_loss: 5.8823 - y1_output_root_mean_squared_error: 1.5306 - y2_output_root_mean_squared_error: 2.4345 - val_loss: 4.4947 - val_y1_output_loss: 0.7045 - val_y2_output_loss: 3.8701 - val_y1_output_root_mean_squared_error: 0.8401 - val_y2_output_root_mean_squared_error: 1.9465
# Epoch 80/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.5223 - y1_output_loss: 1.0001 - y2_output_loss: 3.5053 - y1_output_root_mean_squared_error: 1.0035 - y2_output_root_mean_squared_error: 1.8749 - val_loss: 3.8513 - val_y1_output_loss: 0.5226 - val_y2_output_loss: 3.4246 - val_y1_output_root_mean_squared_error: 0.7333 - val_y2_output_root_mean_squared_error: 1.8203
# Epoch 81/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.5324 - y1_output_loss: 0.6354 - y2_output_loss: 2.8860 - y1_output_root_mean_squared_error: 0.7974 - y2_output_root_mean_squared_error: 1.7019 - val_loss: 12.7774 - val_y1_output_loss: 4.6643 - val_y2_output_loss: 7.8747 - val_y1_output_root_mean_squared_error: 2.1846 - val_y2_output_root_mean_squared_error: 2.8293
# Epoch 82/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.5113 - y1_output_loss: 0.9257 - y2_output_loss: 2.5757 - y1_output_root_mean_squared_error: 0.9638 - y2_output_root_mean_squared_error: 1.6070 - val_loss: 5.2599 - val_y1_output_loss: 1.3428 - val_y2_output_loss: 3.9434 - val_y1_output_root_mean_squared_error: 1.1739 - val_y2_output_root_mean_squared_error: 1.9702
# Epoch 83/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.8343 - y1_output_loss: 2.7950 - y2_output_loss: 6.0495 - y1_output_root_mean_squared_error: 1.6756 - y2_output_root_mean_squared_error: 2.4549 - val_loss: 6.5626 - val_y1_output_loss: 2.0520 - val_y2_output_loss: 4.6822 - val_y1_output_root_mean_squared_error: 1.4403 - val_y2_output_root_mean_squared_error: 2.1185
# Epoch 84/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.4935 - y1_output_loss: 0.8501 - y2_output_loss: 2.6214 - y1_output_root_mean_squared_error: 0.9262 - y2_output_root_mean_squared_error: 1.6235 - val_loss: 4.2192 - val_y1_output_loss: 0.6943 - val_y2_output_loss: 3.5739 - val_y1_output_root_mean_squared_error: 0.8415 - val_y2_output_root_mean_squared_error: 1.8738
# Epoch 85/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.1618 - y1_output_loss: 0.7818 - y2_output_loss: 3.3738 - y1_output_root_mean_squared_error: 0.8877 - y2_output_root_mean_squared_error: 1.8368 - val_loss: 4.1922 - val_y1_output_loss: 0.5348 - val_y2_output_loss: 3.6840 - val_y1_output_root_mean_squared_error: 0.7330 - val_y2_output_root_mean_squared_error: 1.9118
# Epoch 86/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.2190 - y1_output_loss: 0.6999 - y2_output_loss: 2.5079 - y1_output_root_mean_squared_error: 0.8400 - y2_output_root_mean_squared_error: 1.5854 - val_loss: 4.3734 - val_y1_output_loss: 0.5627 - val_y2_output_loss: 4.0219 - val_y1_output_root_mean_squared_error: 0.7416 - val_y2_output_root_mean_squared_error: 1.9554
# Epoch 87/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.0602 - y1_output_loss: 0.6164 - y2_output_loss: 2.4260 - y1_output_root_mean_squared_error: 0.7861 - y2_output_root_mean_squared_error: 1.5628 - val_loss: 3.8475 - val_y1_output_loss: 0.6960 - val_y2_output_loss: 3.2644 - val_y1_output_root_mean_squared_error: 0.8450 - val_y2_output_root_mean_squared_error: 1.7702
# Epoch 88/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.0471 - y1_output_loss: 0.9037 - y2_output_loss: 3.1586 - y1_output_root_mean_squared_error: 0.9452 - y2_output_root_mean_squared_error: 1.7759 - val_loss: 11.1518 - val_y1_output_loss: 3.4848 - val_y2_output_loss: 7.5250 - val_y1_output_root_mean_squared_error: 1.8694 - val_y2_output_root_mean_squared_error: 2.7671
# Epoch 89/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.6745 - y1_output_loss: 0.5333 - y2_output_loss: 2.2070 - y1_output_root_mean_squared_error: 0.7293 - y2_output_root_mean_squared_error: 1.4638 - val_loss: 5.4334 - val_y1_output_loss: 0.8328 - val_y2_output_loss: 4.8208 - val_y1_output_root_mean_squared_error: 0.9180 - val_y2_output_root_mean_squared_error: 2.1426
# Epoch 90/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.7946 - y1_output_loss: 0.5138 - y2_output_loss: 2.3426 - y1_output_root_mean_squared_error: 0.7171 - y2_output_root_mean_squared_error: 1.5101 - val_loss: 5.1991 - val_y1_output_loss: 1.2682 - val_y2_output_loss: 3.9656 - val_y1_output_root_mean_squared_error: 1.1260 - val_y2_output_root_mean_squared_error: 1.9828
# Epoch 91/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.4254 - y1_output_loss: 1.0718 - y2_output_loss: 3.3287 - y1_output_root_mean_squared_error: 1.0384 - y2_output_root_mean_squared_error: 1.8295 - val_loss: 5.5534 - val_y1_output_loss: 1.0759 - val_y2_output_loss: 4.4420 - val_y1_output_root_mean_squared_error: 1.0426 - val_y2_output_root_mean_squared_error: 2.1134
# Epoch 92/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.1747 - y1_output_loss: 1.6553 - y2_output_loss: 4.5001 - y1_output_root_mean_squared_error: 1.2880 - y2_output_root_mean_squared_error: 2.1250 - val_loss: 6.1115 - val_y1_output_loss: 1.4533 - val_y2_output_loss: 4.9301 - val_y1_output_root_mean_squared_error: 1.2258 - val_y2_output_root_mean_squared_error: 2.1468
# Epoch 93/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.7962 - y1_output_loss: 0.6221 - y2_output_loss: 2.1674 - y1_output_root_mean_squared_error: 0.7862 - y2_output_root_mean_squared_error: 1.4758 - val_loss: 7.1737 - val_y1_output_loss: 1.5338 - val_y2_output_loss: 5.8457 - val_y1_output_root_mean_squared_error: 1.2593 - val_y2_output_root_mean_squared_error: 2.3639
# Epoch 94/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.8069 - y1_output_loss: 0.8026 - y2_output_loss: 2.9844 - y1_output_root_mean_squared_error: 0.8924 - y2_output_root_mean_squared_error: 1.7351 - val_loss: 3.6376 - val_y1_output_loss: 0.6515 - val_y2_output_loss: 3.1104 - val_y1_output_root_mean_squared_error: 0.8095 - val_y2_output_root_mean_squared_error: 1.7270
# Epoch 95/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.5193 - y1_output_loss: 0.4894 - y2_output_loss: 2.0456 - y1_output_root_mean_squared_error: 0.7016 - y2_output_root_mean_squared_error: 1.4237 - val_loss: 5.4517 - val_y1_output_loss: 0.8105 - val_y2_output_loss: 4.8795 - val_y1_output_root_mean_squared_error: 0.9044 - val_y2_output_root_mean_squared_error: 2.1526
# Epoch 96/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.0851 - y1_output_loss: 0.5952 - y2_output_loss: 2.4699 - y1_output_root_mean_squared_error: 0.7728 - y2_output_root_mean_squared_error: 1.5773 - val_loss: 2.9377 - val_y1_output_loss: 0.3763 - val_y2_output_loss: 2.6808 - val_y1_output_root_mean_squared_error: 0.6203 - val_y2_output_root_mean_squared_error: 1.5978
# Epoch 97/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.0549 - y1_output_loss: 0.6929 - y2_output_loss: 2.3481 - y1_output_root_mean_squared_error: 0.8364 - y2_output_root_mean_squared_error: 1.5347 - val_loss: 3.7765 - val_y1_output_loss: 0.5232 - val_y2_output_loss: 3.4717 - val_y1_output_root_mean_squared_error: 0.7163 - val_y2_output_root_mean_squared_error: 1.8065
# Epoch 98/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.0622 - y1_output_loss: 0.5538 - y2_output_loss: 2.4839 - y1_output_root_mean_squared_error: 0.7451 - y2_output_root_mean_squared_error: 1.5834 - val_loss: 3.2226 - val_y1_output_loss: 0.4630 - val_y2_output_loss: 2.7968 - val_y1_output_root_mean_squared_error: 0.6791 - val_y2_output_root_mean_squared_error: 1.6618
# Epoch 99/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.1493 - y1_output_loss: 0.7599 - y2_output_loss: 2.3795 - y1_output_root_mean_squared_error: 0.8747 - y2_output_root_mean_squared_error: 1.5441 - val_loss: 3.0524 - val_y1_output_loss: 0.4635 - val_y2_output_loss: 2.6445 - val_y1_output_root_mean_squared_error: 0.6887 - val_y2_output_root_mean_squared_error: 1.6057
# Epoch 100/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.7504 - y1_output_loss: 0.4554 - y2_output_loss: 2.3199 - y1_output_root_mean_squared_error: 0.6775 - y2_output_root_mean_squared_error: 1.5137 - val_loss: 7.3800 - val_y1_output_loss: 0.9576 - val_y2_output_loss: 6.3660 - val_y1_output_root_mean_squared_error: 0.9753 - val_y2_output_root_mean_squared_error: 2.5355
# Epoch 101/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.0872 - y1_output_loss: 0.6618 - y2_output_loss: 2.4156 - y1_output_root_mean_squared_error: 0.8147 - y2_output_root_mean_squared_error: 1.5567 - val_loss: 3.8903 - val_y1_output_loss: 0.6706 - val_y2_output_loss: 3.2316 - val_y1_output_root_mean_squared_error: 0.8261 - val_y2_output_root_mean_squared_error: 1.7910
# Epoch 102/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.2299 - y1_output_loss: 0.6544 - y2_output_loss: 2.5570 - y1_output_root_mean_squared_error: 0.8064 - y2_output_root_mean_squared_error: 1.6061 - val_loss: 3.0395 - val_y1_output_loss: 0.4456 - val_y2_output_loss: 2.7536 - val_y1_output_root_mean_squared_error: 0.6692 - val_y2_output_root_mean_squared_error: 1.6099
# Epoch 103/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.6294 - y1_output_loss: 0.5813 - y2_output_loss: 2.0407 - y1_output_root_mean_squared_error: 0.7655 - y2_output_root_mean_squared_error: 1.4295 - val_loss: 4.9824 - val_y1_output_loss: 0.5005 - val_y2_output_loss: 4.6968 - val_y1_output_root_mean_squared_error: 0.7097 - val_y2_output_root_mean_squared_error: 2.1163
# Epoch 104/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.5718 - y1_output_loss: 0.4833 - y2_output_loss: 2.0676 - y1_output_root_mean_squared_error: 0.6976 - y2_output_root_mean_squared_error: 1.4440 - val_loss: 5.1395 - val_y1_output_loss: 1.0864 - val_y2_output_loss: 4.1741 - val_y1_output_root_mean_squared_error: 1.0579 - val_y2_output_root_mean_squared_error: 2.0051
# Epoch 105/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.2656 - y1_output_loss: 2.1272 - y2_output_loss: 6.0611 - y1_output_root_mean_squared_error: 1.4654 - y2_output_root_mean_squared_error: 2.4735 - val_loss: 4.8547 - val_y1_output_loss: 1.3856 - val_y2_output_loss: 3.5980 - val_y1_output_root_mean_squared_error: 1.1893 - val_y2_output_root_mean_squared_error: 1.8548
# Epoch 106/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.2670 - y1_output_loss: 0.6451 - y2_output_loss: 2.6655 - y1_output_root_mean_squared_error: 0.8062 - y2_output_root_mean_squared_error: 1.6177 - val_loss: 8.0318 - val_y1_output_loss: 0.9610 - val_y2_output_loss: 7.3519 - val_y1_output_root_mean_squared_error: 0.9922 - val_y2_output_root_mean_squared_error: 2.6547
# Epoch 107/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.7924 - y1_output_loss: 0.5698 - y2_output_loss: 2.2067 - y1_output_root_mean_squared_error: 0.7569 - y2_output_root_mean_squared_error: 1.4898 - val_loss: 3.4963 - val_y1_output_loss: 0.6401 - val_y2_output_loss: 3.0518 - val_y1_output_root_mean_squared_error: 0.8064 - val_y2_output_root_mean_squared_error: 1.6870
# Epoch 108/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.2000 - y1_output_loss: 0.4376 - y2_output_loss: 1.7765 - y1_output_root_mean_squared_error: 0.6633 - y2_output_root_mean_squared_error: 1.3266 - val_loss: 3.1246 - val_y1_output_loss: 0.6112 - val_y2_output_loss: 2.5965 - val_y1_output_root_mean_squared_error: 0.7827 - val_y2_output_root_mean_squared_error: 1.5849
# Epoch 109/500
# 614/614 [==============================] - 0s 166us/sample - loss: 2.6524 - y1_output_loss: 0.5660 - y2_output_loss: 2.0884 - y1_output_root_mean_squared_error: 0.7543 - y2_output_root_mean_squared_error: 1.4434 - val_loss: 5.5027 - val_y1_output_loss: 0.7981 - val_y2_output_loss: 4.6718 - val_y1_output_root_mean_squared_error: 0.8922 - val_y2_output_root_mean_squared_error: 2.1695
# Epoch 110/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.2613 - y1_output_loss: 0.4763 - y2_output_loss: 1.8042 - y1_output_root_mean_squared_error: 0.6908 - y2_output_root_mean_squared_error: 1.3357 - val_loss: 3.9253 - val_y1_output_loss: 0.4019 - val_y2_output_loss: 3.7244 - val_y1_output_root_mean_squared_error: 0.6432 - val_y2_output_root_mean_squared_error: 1.8739
# Epoch 111/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.7159 - y1_output_loss: 0.5606 - y2_output_loss: 2.1529 - y1_output_root_mean_squared_error: 0.7491 - y2_output_root_mean_squared_error: 1.4679 - val_loss: 3.0668 - val_y1_output_loss: 0.3749 - val_y2_output_loss: 2.8589 - val_y1_output_root_mean_squared_error: 0.6121 - val_y2_output_root_mean_squared_error: 1.6408
# Epoch 112/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.9085 - y1_output_loss: 0.6380 - y2_output_loss: 2.2443 - y1_output_root_mean_squared_error: 0.8022 - y2_output_root_mean_squared_error: 1.5050 - val_loss: 3.0226 - val_y1_output_loss: 0.5042 - val_y2_output_loss: 2.6720 - val_y1_output_root_mean_squared_error: 0.7009 - val_y2_output_root_mean_squared_error: 1.5910
# Epoch 113/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.0354 - y1_output_loss: 0.5183 - y2_output_loss: 2.4969 - y1_output_root_mean_squared_error: 0.7221 - y2_output_root_mean_squared_error: 1.5856 - val_loss: 4.0433 - val_y1_output_loss: 0.9092 - val_y2_output_loss: 3.1533 - val_y1_output_root_mean_squared_error: 0.9570 - val_y2_output_root_mean_squared_error: 1.7685
# Epoch 114/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.6756 - y1_output_loss: 0.5867 - y2_output_loss: 2.0665 - y1_output_root_mean_squared_error: 0.7695 - y2_output_root_mean_squared_error: 1.4434 - val_loss: 3.0657 - val_y1_output_loss: 0.4163 - val_y2_output_loss: 2.7878 - val_y1_output_root_mean_squared_error: 0.6374 - val_y2_output_root_mean_squared_error: 1.6308
# Epoch 115/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.0373 - y1_output_loss: 0.4058 - y2_output_loss: 1.6191 - y1_output_root_mean_squared_error: 0.6400 - y2_output_root_mean_squared_error: 1.2758 - val_loss: 2.9353 - val_y1_output_loss: 0.6162 - val_y2_output_loss: 2.3665 - val_y1_output_root_mean_squared_error: 0.7800 - val_y2_output_root_mean_squared_error: 1.5254
# Epoch 116/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.1257 - y1_output_loss: 0.6109 - y2_output_loss: 2.4916 - y1_output_root_mean_squared_error: 0.7831 - y2_output_root_mean_squared_error: 1.5851 - val_loss: 3.2163 - val_y1_output_loss: 0.4427 - val_y2_output_loss: 2.9168 - val_y1_output_root_mean_squared_error: 0.6702 - val_y2_output_root_mean_squared_error: 1.6634
# Epoch 117/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.3048 - y1_output_loss: 0.6197 - y2_output_loss: 2.6730 - y1_output_root_mean_squared_error: 0.7900 - y2_output_root_mean_squared_error: 1.6373 - val_loss: 3.0020 - val_y1_output_loss: 0.3462 - val_y2_output_loss: 2.6699 - val_y1_output_root_mean_squared_error: 0.5818 - val_y2_output_root_mean_squared_error: 1.6320
# Epoch 118/500
# 614/614 [==============================] - 0s 139us/sample - loss: 18.2998 - y1_output_loss: 6.2764 - y2_output_loss: 11.8557 - y1_output_root_mean_squared_error: 2.5166 - y2_output_root_mean_squared_error: 3.4593 - val_loss: 4.0620 - val_y1_output_loss: 0.5969 - val_y2_output_loss: 3.7734 - val_y1_output_root_mean_squared_error: 0.7847 - val_y2_output_root_mean_squared_error: 1.8564
# Epoch 119/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.8409 - y1_output_loss: 0.5786 - y2_output_loss: 2.2570 - y1_output_root_mean_squared_error: 0.7616 - y2_output_root_mean_squared_error: 1.5036 - val_loss: 5.9223 - val_y1_output_loss: 1.3248 - val_y2_output_loss: 4.5462 - val_y1_output_root_mean_squared_error: 1.1592 - val_y2_output_root_mean_squared_error: 2.1397
# Epoch 120/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.4285 - y1_output_loss: 0.5250 - y2_output_loss: 1.9345 - y1_output_root_mean_squared_error: 0.7183 - y2_output_root_mean_squared_error: 1.3829 - val_loss: 3.8206 - val_y1_output_loss: 0.4151 - val_y2_output_loss: 3.6551 - val_y1_output_root_mean_squared_error: 0.6514 - val_y2_output_root_mean_squared_error: 1.8429
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4388 - y1_output_loss: 0.1358 - y2_output_loss: 0.3084 - y1_output_root_mean_squared_error: 0.3699 - y2_output_root_mean_squared_error: 0.5495 - val_loss: 2.4675 - val_y1_output_loss: 0.1928 - val_y2_output_loss: 2.3177 - val_y1_output_root_mean_squared_error: 0.4373 - val_y2_output_root_mean_squared_error: 1.5087
# Epoch 462/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.5359 - y1_output_loss: 0.1407 - y2_output_loss: 0.3936 - y1_output_root_mean_squared_error: 0.3749 - y2_output_root_mean_squared_error: 0.6287 - val_loss: 0.8483 - val_y1_output_loss: 0.2115 - val_y2_output_loss: 0.6395 - val_y1_output_root_mean_squared_error: 0.4569 - val_y2_output_root_mean_squared_error: 0.7997
# Epoch 463/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4667 - y1_output_loss: 0.1298 - y2_output_loss: 0.3335 - y1_output_root_mean_squared_error: 0.3609 - y2_output_root_mean_squared_error: 0.5801 - val_loss: 0.9129 - val_y1_output_loss: 0.2072 - val_y2_output_loss: 0.7001 - val_y1_output_root_mean_squared_error: 0.4548 - val_y2_output_root_mean_squared_error: 0.8402
# Epoch 464/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3930 - y1_output_loss: 0.1082 - y2_output_loss: 0.2848 - y1_output_root_mean_squared_error: 0.3301 - y2_output_root_mean_squared_error: 0.5330 - val_loss: 1.2043 - val_y1_output_loss: 0.2176 - val_y2_output_loss: 1.0216 - val_y1_output_root_mean_squared_error: 0.4640 - val_y2_output_root_mean_squared_error: 0.9945
# Epoch 465/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4412 - y1_output_loss: 0.1351 - y2_output_loss: 0.3060 - y1_output_root_mean_squared_error: 0.3672 - y2_output_root_mean_squared_error: 0.5535 - val_loss: 1.5406 - val_y1_output_loss: 0.4980 - val_y2_output_loss: 1.0401 - val_y1_output_root_mean_squared_error: 0.7126 - val_y2_output_root_mean_squared_error: 1.0163
# Epoch 466/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4164 - y1_output_loss: 0.1311 - y2_output_loss: 0.2865 - y1_output_root_mean_squared_error: 0.3615 - y2_output_root_mean_squared_error: 0.5345 - val_loss: 1.4050 - val_y1_output_loss: 0.4421 - val_y2_output_loss: 0.9663 - val_y1_output_root_mean_squared_error: 0.6608 - val_y2_output_root_mean_squared_error: 0.9840
# Epoch 467/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4728 - y1_output_loss: 0.1281 - y2_output_loss: 0.3481 - y1_output_root_mean_squared_error: 0.3588 - y2_output_root_mean_squared_error: 0.5865 - val_loss: 1.4320 - val_y1_output_loss: 0.1627 - val_y2_output_loss: 1.3049 - val_y1_output_root_mean_squared_error: 0.3994 - val_y2_output_root_mean_squared_error: 1.1280
# Epoch 468/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4061 - y1_output_loss: 0.1284 - y2_output_loss: 0.2751 - y1_output_root_mean_squared_error: 0.3589 - y2_output_root_mean_squared_error: 0.5266 - val_loss: 0.8203 - val_y1_output_loss: 0.2072 - val_y2_output_loss: 0.6213 - val_y1_output_root_mean_squared_error: 0.4492 - val_y2_output_root_mean_squared_error: 0.7864
# Epoch 469/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4378 - y1_output_loss: 0.1195 - y2_output_loss: 0.3216 - y1_output_root_mean_squared_error: 0.3466 - y2_output_root_mean_squared_error: 0.5636 - val_loss: 1.2969 - val_y1_output_loss: 0.1968 - val_y2_output_loss: 1.1228 - val_y1_output_root_mean_squared_error: 0.4439 - val_y2_output_root_mean_squared_error: 1.0488
# Epoch 470/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.4419 - y1_output_loss: 0.1367 - y2_output_loss: 0.3098 - y1_output_root_mean_squared_error: 0.3707 - y2_output_root_mean_squared_error: 0.5518 - val_loss: 2.3307 - val_y1_output_loss: 0.2119 - val_y2_output_loss: 2.1470 - val_y1_output_root_mean_squared_error: 0.4601 - val_y2_output_root_mean_squared_error: 1.4557
# Epoch 471/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.5852 - y1_output_loss: 0.1575 - y2_output_loss: 0.4233 - y1_output_root_mean_squared_error: 0.3978 - y2_output_root_mean_squared_error: 0.6534 - val_loss: 0.8221 - val_y1_output_loss: 0.1699 - val_y2_output_loss: 0.6663 - val_y1_output_root_mean_squared_error: 0.4053 - val_y2_output_root_mean_squared_error: 0.8111
# Epoch 472/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4172 - y1_output_loss: 0.1376 - y2_output_loss: 0.2837 - y1_output_root_mean_squared_error: 0.3701 - y2_output_root_mean_squared_error: 0.5293 - val_loss: 1.4903 - val_y1_output_loss: 0.2388 - val_y2_output_loss: 1.2617 - val_y1_output_root_mean_squared_error: 0.4920 - val_y2_output_root_mean_squared_error: 1.1173
# Epoch 473/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.6520 - y1_output_loss: 0.2111 - y2_output_loss: 0.4378 - y1_output_root_mean_squared_error: 0.4589 - y2_output_root_mean_squared_error: 0.6644 - val_loss: 1.0624 - val_y1_output_loss: 0.2559 - val_y2_output_loss: 0.8415 - val_y1_output_root_mean_squared_error: 0.4978 - val_y2_output_root_mean_squared_error: 0.9026
# Epoch 474/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.6135 - y1_output_loss: 0.1443 - y2_output_loss: 0.4677 - y1_output_root_mean_squared_error: 0.3804 - y2_output_root_mean_squared_error: 0.6846 - val_loss: 2.0812 - val_y1_output_loss: 0.3012 - val_y2_output_loss: 1.8348 - val_y1_output_root_mean_squared_error: 0.5482 - val_y2_output_root_mean_squared_error: 1.3344
# Epoch 475/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4051 - y1_output_loss: 0.1216 - y2_output_loss: 0.2825 - y1_output_root_mean_squared_error: 0.3493 - y2_output_root_mean_squared_error: 0.5320 - val_loss: 0.8537 - val_y1_output_loss: 0.1956 - val_y2_output_loss: 0.6638 - val_y1_output_root_mean_squared_error: 0.4408 - val_y2_output_root_mean_squared_error: 0.8121
# Epoch 476/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.5195 - y1_output_loss: 0.1498 - y2_output_loss: 0.3651 - y1_output_root_mean_squared_error: 0.3886 - y2_output_root_mean_squared_error: 0.6071 - val_loss: 0.9395 - val_y1_output_loss: 0.2104 - val_y2_output_loss: 0.7339 - val_y1_output_root_mean_squared_error: 0.4506 - val_y2_output_root_mean_squared_error: 0.8582
# Epoch 477/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3751 - y1_output_loss: 0.1161 - y2_output_loss: 0.2561 - y1_output_root_mean_squared_error: 0.3421 - y2_output_root_mean_squared_error: 0.5080 - val_loss: 0.8070 - val_y1_output_loss: 0.1755 - val_y2_output_loss: 0.6451 - val_y1_output_root_mean_squared_error: 0.4119 - val_y2_output_root_mean_squared_error: 0.7983
# Epoch 478/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4183 - y1_output_loss: 0.1245 - y2_output_loss: 0.2937 - y1_output_root_mean_squared_error: 0.3536 - y2_output_root_mean_squared_error: 0.5416 - val_loss: 1.2995 - val_y1_output_loss: 0.2637 - val_y2_output_loss: 1.0370 - val_y1_output_root_mean_squared_error: 0.5069 - val_y2_output_root_mean_squared_error: 1.0210
# Epoch 479/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3779 - y1_output_loss: 0.1284 - y2_output_loss: 0.2514 - y1_output_root_mean_squared_error: 0.3578 - y2_output_root_mean_squared_error: 0.4999 - val_loss: 0.8161 - val_y1_output_loss: 0.1952 - val_y2_output_loss: 0.6276 - val_y1_output_root_mean_squared_error: 0.4387 - val_y2_output_root_mean_squared_error: 0.7897
# Epoch 480/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4442 - y1_output_loss: 0.1378 - y2_output_loss: 0.3175 - y1_output_root_mean_squared_error: 0.3707 - y2_output_root_mean_squared_error: 0.5539 - val_loss: 2.7514 - val_y1_output_loss: 0.3005 - val_y2_output_loss: 2.4925 - val_y1_output_root_mean_squared_error: 0.5470 - val_y2_output_root_mean_squared_error: 1.5659
# Epoch 481/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4079 - y1_output_loss: 0.1180 - y2_output_loss: 0.2869 - y1_output_root_mean_squared_error: 0.3446 - y2_output_root_mean_squared_error: 0.5377 - val_loss: 0.9025 - val_y1_output_loss: 0.1709 - val_y2_output_loss: 0.7667 - val_y1_output_root_mean_squared_error: 0.4075 - val_y2_output_root_mean_squared_error: 0.8582
# Epoch 482/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4414 - y1_output_loss: 0.1409 - y2_output_loss: 0.3088 - y1_output_root_mean_squared_error: 0.3695 - y2_output_root_mean_squared_error: 0.5521 - val_loss: 2.4477 - val_y1_output_loss: 0.4558 - val_y2_output_loss: 2.0586 - val_y1_output_root_mean_squared_error: 0.6742 - val_y2_output_root_mean_squared_error: 1.4118
# Epoch 483/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3829 - y1_output_loss: 0.1236 - y2_output_loss: 0.2642 - y1_output_root_mean_squared_error: 0.3518 - y2_output_root_mean_squared_error: 0.5090 - val_loss: 1.0784 - val_y1_output_loss: 0.2531 - val_y2_output_loss: 0.8263 - val_y1_output_root_mean_squared_error: 0.4968 - val_y2_output_root_mean_squared_error: 0.9119
# Epoch 484/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3665 - y1_output_loss: 0.1135 - y2_output_loss: 0.2515 - y1_output_root_mean_squared_error: 0.3378 - y2_output_root_mean_squared_error: 0.5024 - val_loss: 0.8004 - val_y1_output_loss: 0.1712 - val_y2_output_loss: 0.6337 - val_y1_output_root_mean_squared_error: 0.4092 - val_y2_output_root_mean_squared_error: 0.7956
# Epoch 485/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3958 - y1_output_loss: 0.1266 - y2_output_loss: 0.2712 - y1_output_root_mean_squared_error: 0.3571 - y2_output_root_mean_squared_error: 0.5179 - val_loss: 2.0405 - val_y1_output_loss: 0.2125 - val_y2_output_loss: 1.8579 - val_y1_output_root_mean_squared_error: 0.4606 - val_y2_output_root_mean_squared_error: 1.3521
# Epoch 486/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4456 - y1_output_loss: 0.1149 - y2_output_loss: 0.3325 - y1_output_root_mean_squared_error: 0.3373 - y2_output_root_mean_squared_error: 0.5761 - val_loss: 1.4692 - val_y1_output_loss: 0.2712 - val_y2_output_loss: 1.2309 - val_y1_output_root_mean_squared_error: 0.5168 - val_y2_output_root_mean_squared_error: 1.0964
# Epoch 487/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3423 - y1_output_loss: 0.1069 - y2_output_loss: 0.2331 - y1_output_root_mean_squared_error: 0.3280 - y2_output_root_mean_squared_error: 0.4845 - val_loss: 0.7574 - val_y1_output_loss: 0.1922 - val_y2_output_loss: 0.5746 - val_y1_output_root_mean_squared_error: 0.4333 - val_y2_output_root_mean_squared_error: 0.7547
# Epoch 488/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3663 - y1_output_loss: 0.1140 - y2_output_loss: 0.2552 - y1_output_root_mean_squared_error: 0.3371 - y2_output_root_mean_squared_error: 0.5027 - val_loss: 2.3101 - val_y1_output_loss: 0.3786 - val_y2_output_loss: 1.9632 - val_y1_output_root_mean_squared_error: 0.6202 - val_y2_output_root_mean_squared_error: 1.3876
# Epoch 489/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4003 - y1_output_loss: 0.1159 - y2_output_loss: 0.2954 - y1_output_root_mean_squared_error: 0.3416 - y2_output_root_mean_squared_error: 0.5326 - val_loss: 2.4182 - val_y1_output_loss: 0.1790 - val_y2_output_loss: 2.2816 - val_y1_output_root_mean_squared_error: 0.4211 - val_y2_output_root_mean_squared_error: 1.4970
# Epoch 490/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.5644 - y1_output_loss: 0.1590 - y2_output_loss: 0.4010 - y1_output_root_mean_squared_error: 0.3996 - y2_output_root_mean_squared_error: 0.6362 - val_loss: 0.7336 - val_y1_output_loss: 0.1603 - val_y2_output_loss: 0.5730 - val_y1_output_root_mean_squared_error: 0.3966 - val_y2_output_root_mean_squared_error: 0.7591
# Epoch 491/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3319 - y1_output_loss: 0.1108 - y2_output_loss: 0.2199 - y1_output_root_mean_squared_error: 0.3325 - y2_output_root_mean_squared_error: 0.4705 - val_loss: 0.9063 - val_y1_output_loss: 0.2131 - val_y2_output_loss: 0.7163 - val_y1_output_root_mean_squared_error: 0.4542 - val_y2_output_root_mean_squared_error: 0.8367
# Epoch 492/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3678 - y1_output_loss: 0.1105 - y2_output_loss: 0.2564 - y1_output_root_mean_squared_error: 0.3326 - y2_output_root_mean_squared_error: 0.5071 - val_loss: 0.8375 - val_y1_output_loss: 0.1903 - val_y2_output_loss: 0.6573 - val_y1_output_root_mean_squared_error: 0.4332 - val_y2_output_root_mean_squared_error: 0.8061
# Epoch 493/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3688 - y1_output_loss: 0.1169 - y2_output_loss: 0.2501 - y1_output_root_mean_squared_error: 0.3422 - y2_output_root_mean_squared_error: 0.5017 - val_loss: 0.8779 - val_y1_output_loss: 0.2237 - val_y2_output_loss: 0.6595 - val_y1_output_root_mean_squared_error: 0.4648 - val_y2_output_root_mean_squared_error: 0.8135
# Epoch 494/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3112 - y1_output_loss: 0.1154 - y2_output_loss: 0.1963 - y1_output_root_mean_squared_error: 0.3400 - y2_output_root_mean_squared_error: 0.4423 - val_loss: 1.2931 - val_y1_output_loss: 0.2621 - val_y2_output_loss: 1.0673 - val_y1_output_root_mean_squared_error: 0.5070 - val_y2_output_root_mean_squared_error: 1.0179
# Epoch 495/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.6489 - y1_output_loss: 0.1736 - y2_output_loss: 0.4722 - y1_output_root_mean_squared_error: 0.4186 - y2_output_root_mean_squared_error: 0.6882 - val_loss: 1.4014 - val_y1_output_loss: 0.2449 - val_y2_output_loss: 1.1322 - val_y1_output_root_mean_squared_error: 0.4957 - val_y2_output_root_mean_squared_error: 1.0750
# Epoch 496/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3607 - y1_output_loss: 0.1064 - y2_output_loss: 0.2556 - y1_output_root_mean_squared_error: 0.3256 - y2_output_root_mean_squared_error: 0.5047 - val_loss: 0.9646 - val_y1_output_loss: 0.1996 - val_y2_output_loss: 0.7700 - val_y1_output_root_mean_squared_error: 0.4426 - val_y2_output_root_mean_squared_error: 0.8768
# Epoch 497/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3534 - y1_output_loss: 0.1203 - y2_output_loss: 0.2316 - y1_output_root_mean_squared_error: 0.3463 - y2_output_root_mean_squared_error: 0.4832 - val_loss: 1.0128 - val_y1_output_loss: 0.3304 - val_y2_output_loss: 0.6942 - val_y1_output_root_mean_squared_error: 0.5696 - val_y2_output_root_mean_squared_error: 0.8297
# Epoch 498/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4182 - y1_output_loss: 0.1241 - y2_output_loss: 0.2910 - y1_output_root_mean_squared_error: 0.3536 - y2_output_root_mean_squared_error: 0.5414 - val_loss: 0.7572 - val_y1_output_loss: 0.1697 - val_y2_output_loss: 0.5967 - val_y1_output_root_mean_squared_error: 0.4039 - val_y2_output_root_mean_squared_error: 0.7708
# Epoch 499/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3294 - y1_output_loss: 0.1075 - y2_output_loss: 0.2245 - y1_output_root_mean_squared_error: 0.3282 - y2_output_root_mean_squared_error: 0.4709 - val_loss: 1.1371 - val_y1_output_loss: 0.1540 - val_y2_output_loss: 1.0036 - val_y1_output_root_mean_squared_error: 0.3850 - val_y2_output_root_mean_squared_error: 0.9944
# Epoch 500/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3720 - y1_output_loss: 0.1159 - y2_output_loss: 0.2547 - y1_output_root_mean_squared_error: 0.3413 - y2_output_root_mean_squared_error: 0.5055 - val_loss: 1.1853 - val_y1_output_loss: 0.1687 - val_y2_output_loss: 1.0474 - val_y1_output_root_mean_squared_error: 0.4050 - val_y2_output_root_mean_squared_error: 1.0106

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 35us/sample - loss: 1.1853 - y1_output_loss: 0.1646 - y2_output_loss: 1.0397 - y1_output_root_mean_squared_error: 0.4050 - y2_output_root_mean_squared_error: 1.0106
# Loss = 1.1852557272106021, Y1_loss = 0.1646309494972229, Y1_mse = 0.40500932931900024, Y2_loss = 1.0396521091461182, Y2_mse = 1.0105558633804321

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
